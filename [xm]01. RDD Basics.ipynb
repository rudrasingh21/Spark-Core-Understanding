# %% [raw]
# NOTE:- We have given 3 for creating 3 Partition ,
#         If we will not specify it , it will create partition as     defined in settings

# %%
L = sc.parallelize([1,2,3,4,5,6,78,9,10],3)

# %%
L
# Out:
# ParallelCollectionRDD[11] at parallelize at PythonRDD.scala:489

# %% [raw]
# NOTE:- you can see ParallelCollectionRDD

# %%
L.collect()
# Out:
# [1, 2, 3, 4, 5, 6, 78, 9, 10]

# %%
L.getNumPartitions()
# Out:
# 3

# %% [raw]
# Use glom() to see our data within Partition

# %%
L.glom()
# Out:
# PythonRDD[13] at RDD at PythonRDD.scala:48

# %%
L.glom().collect()
# Out:
# [[1, 2, 3], [4, 5, 6], [78, 9, 10]]

# %% [raw]
# NOTE:- You can see 3 partition of RDD

# %%
dir(L)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_computeFractionForSampleSize',
#  '_defaultReducePartitions',
#  '_id',
#  '_jrdd',
#  '_jrdd_deserializer',
#  '_memory_limit',
#  '_pickled',
#  '_reserialize',
#  '_to_java_object_rdd',
#  'aggregate',
#  'aggregateByKey',
#  'cache',
#  'cartesian',
#  'checkpoint',
#  'coalesce',
#  'cogroup',
#  'collect',
#  'collectAsMap',
#  'combineByKey',
#  'context',
#  'count',
#  'countApprox',
#  'countApproxDistinct',
#  'countByKey',
#  'countByValue',
#  'ctx',
#  'distinct',
#  'filter',
#  'first',
#  'flatMap',
# ...

# %%
help(L)
# Out:
# Help on RDD in module pyspark.rdd object:
#
# class RDD(builtins.object)
#  |  A Resilient Distributed Dataset (RDD), the basic abstraction in Spark.
#  |  Represents an immutable, partitioned collection of elements that can be
#  |  operated on in parallel.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, other)
#  |      Return the union of this RDD and another one.
#  |
#  |      >>> rdd = sc.parallelize([1, 1, 2, 3])
#  |      >>> (rdd + rdd).collect()
#  |      [1, 1, 2, 3, 1, 1, 2, 3]
#  |
#  |  __getnewargs__(self)
#  |
#  |  __init__(self, jrdd, ctx, jrdd_deserializer=AutoBatchedSerializer(PickleSerializer()))
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  aggregate(self, zeroValue, seqOp, combOp)
#  |      Aggregate the elements of each partition, and then the results for all
#  |      the partitions, using a given combine functions and a neutral "zero
#  |      value."
#  |
# ...

# %%
L.sum()
# Out:
# 118

# %%
L.min()
# Out:
# 1

# %%
L.max()
# Out:
# 78

# %%
L.mean()
# Out:
# 13.11111111111111

# %%
L.first()
# Out:
# 1

# %% [raw]
# RDD Can hold different type of Objects

# %%
List_dif_types = sc.parallelize([False, 1, "two", {'three': 3}, ('xavier',4)])

# %% [raw]
# Above :- Boolean , int, string , dictionary, list

# %%
List_dif_types
# Out:
# ParallelCollectionRDD[20] at parallelize at PythonRDD.scala:489

# %% [raw]
# NOTE:- You can see RDD name :- ParallelCollectionRDD[20]

# %% [raw]
# Renameing RDD:-

# %%
List_dif_types.setName("TestRDD")
# Out:
# TestRDD ParallelCollectionRDD[20] at parallelize at PythonRDD.scala:489

# %% [raw]
# Very Useful to identitiying RDD

# %% [markdown]
# # Creating Empty RDD:-

# %%
empty_rdd = sc.parallelize([])

# %%
empty_rdd.collect()
# Out:
# []

# %%
empty_rdd.isEmpty()
# Out:
# True

# %%
#Other Way

# %%
Other_empty = sc.emptyRDD()

# %%
Other_empty.collect()
# Out:
# []

# %%
Other_empty.isEmpty()
# Out:
# True

# %% [markdown]
# # RDD Using Range()

# %%
Range_RDD = sc.parallelize(range(1,10))

# %%
Range_RDD
# Out:
# PythonRDD[25] at RDD at PythonRDD.scala:48

# %%
Range_RDD.first()
# Out:
# 1

# %% [raw]
# NOTE:- When we execute below commands , data comes back from worker Node to Driver Program.

# %% [raw]
# .collect()

# %% [markdown]
# .first()

# %%
.takeOrdered(10 , key=lambda i: -i)

#will return 10 values 
#using key in reverse order

# %% [markdown]
# # Re- Partitions

# %%
L.getNumPartitions()
# Out:
# 3

# %%
L_Repartitions = L.repartition(5)

# %%
L_Repartitions.getNumPartitions()
# Out:
# 5

# %%
L_Repartitions.glom().collect()
# Out:
# [[], [1, 2, 3, 4, 5, 6], [], [], [78, 9, 10]]

# %% [raw]
# Repartition() vs Coalesce():-

# %% [raw]
# Repartition():- Either Increase or Decrease the number of Partition

# %% [raw]
# Coalesce():- Always decrease the number of partition

# %% [markdown]
# # Listing RDDs:-

# %%
from pyspark import RDD
for (k, v) in locals().items():
    if isinstance(v, RDD):
        print(k)
# Out:
# list
# _2
# _5
# L
# _7
# _10
# _13
# _14
# _15
# _18
# _21
# _24
# _27
# _30
# _31
# List_dif_types
# _43
# _44
# empty_rdd
# Other_empty
# Range_RDD
# _54
# L_Repartitions

# %%
#NOTE:- Above all RDD currently in memory

# %% [markdown]
# # toDebudString()

# %%
print(L_Repartitions.toDebugString())
# Out:
# b'(5) MapPartitionsRDD[31] at coalesce at NativeMethodAccessorImpl.java:0 []\n |  CoalescedRDD[30] at coalesce at NativeMethodAccessorImpl.java:0 []\n |  ShuffledRDD[29] at coalesce at NativeMethodAccessorImpl.java:0 []\n +-(3) MapPartitionsRDD[28] at coalesce at NativeMethodAccessorImpl.java:0 []\n    |  PythonRDD[27] at RDD at PythonRDD.scala:48 []\n    |  ParallelCollectionRDD[11] at parallelize at PythonRDD.scala:489 []'
